# %%
import groq
import os
import json
from IPython.display import display, HTML
import sys
from pathlib import Path

# Add the project root to the Python path
project_root = Path().resolve().parent
sys.path.append(str(project_root))

# Set up Groq client
groq_api_key = os.environ.get("GROQ_API_KEY")
if not groq_api_key:
    raise ValueError("Please set the GROQ_API_KEY environment variable")
client = groq.Groq(api_key=groq_api_key)

# Load data
def load_json(filename):
    file_path = project_root / 'data' / filename
    try:
        with open(file_path, 'r') as f:
            return json.load(f)
    except FileNotFoundError:
        print(f"Error: {filename} not found in {file_path}")
        return {}

recipes = load_json('recipes.json')
seasonal_ingredients = load_json('seasonal_ingredients.json')

# Import custom modules
from src.recipe_generator import generate_recipe
from src.meal_planner import create_meal_plan
from src.nutritional_analyzer import analyze_nutrition
from src.cuisine_fusion import generate_fusion_recipe
from src.shopping_list_generator import generate_shopping_list

# Define get_user_preferences function
def get_user_preferences():
    preferences = {
        "dietary_restrictions": input("Enter any dietary restrictions (comma-separated): ").split(','),
        "cuisine_preferences": input("Enter preferred cuisines (comma-separated): ").split(','),
        "skill_level": input("Enter your cooking skill level (beginner/intermediate/advanced): "),
        "available_ingredients": input("Enter available ingredients (comma-separated): ").split(','),
    }
    return preferences

def main():
    print("Welcome to the Smart Recipe Generator and Meal Planner!")
    user_preferences = get_user_preferences()
    
    # Generate a recipe
    recipe = generate_recipe(client, user_preferences, recipes, seasonal_ingredients)
    display(HTML(f"<h2>Generated Recipe:</h2><pre>{recipe}</pre>"))
    
    # Create a meal plan
    meal_plan = create_meal_plan(client, user_preferences, recipes, seasonal_ingredients)
    display(HTML(f"<h2>Weekly Meal Plan:</h2><pre>{meal_plan}</pre>"))
    
    # Analyze nutrition
    nutrition_analysis = analyze_nutrition(client, meal_plan)
    display(HTML(f"<h2>Nutritional Analysis:</h2><pre>{nutrition_analysis}</pre>"))
    
    # Generate a fusion recipe
    fusion_recipe = generate_fusion_recipe(client, user_preferences, recipes)
    display(HTML(f"<h2>Fusion Recipe:</h2><pre>{fusion_recipe}</pre>"))
    
    # Generate a shopping list
    shopping_list = generate_shopping_list(client, meal_plan)
    display(HTML(f"<h2>Shopping List:</h2><pre>{shopping_list}</pre>"))

if __name__ == "__main__":
    main()
# Out:
# Welcome to the Smart Recipe Generator and Meal Planner!
# Enter any dietary restrictions (comma-separated):  vegetarian, low-sodium
# Enter preferred cuisines (comma-separated):  Italian, Japanese, Mediterranean
# Enter your cooking skill level (beginner/intermediate/advanced):  intermediate
# Enter available ingredients (comma-separated):  chicken, tomatoes, pasta, onions, garlic
# <h2>Generated Recipe:</h2><pre>**Vegetarian Pasta Primavera**
#
# This Italian-inspired springtime dish is a perfect blend of fresh vegetables, herbs, and pasta. Given the dietary restrictions, we will be substituting traditional chicken with a vegetarian alternative, and adjusting the seasonings to accommodate low-sodium requirements.
#
# **Ingredients:**
#
# * 8 oz (225g) Mediterranean pasta (such as orzo or farfalle)
# * 2 cups (250g) mixed spring vegetables (asparagus, artichoke hearts, peas)
# * 1 cup (115g) cherry tomatoes, halved
# * 1/2 cup (115g) low-sodium vegetable broth
# * 2 tbsp (30g) olive oil
# * 1 small onion, chopped
# * 3 cloves garlic, minced
# * 1 tsp (5g) dried basil
# * Salt-free Italian seasoning (or homemade blend using herbs like oregano, thyme, and rosemary)
# * Fresh parsley, chopped (optional)
#
# **Instructions:**
#
# 1. **Prepare the vegetables:** Wash and trim the asparagus. Cut off the tough ends and slice the spears into 1-inch (2.5cm) pieces. Cut the artichoke hearts in half. Shell the peas and set them aside.
#
# 2. **Cook the pasta:** Bring a large pot of salt-free water to a boil. Cook the pasta according to package instructions until al dente. Reserve 1 cup of pasta water before draining.
#
# 3. **Sauté the onion and garlic:** In a large skillet, heat the olive oil over medium heat. Add the chopped onion and cook for 3-4 minutes, until translucent. Add the minced garlic and cook for an additional minute.
#
# 4. **Add the vegetables:** Add the mixed spring vegetables, cherry tomatoes, and low-sodium vegetable broth to the skillet. Cook for 5-7 minutes, until the vegetables are tender but still crisp.
#
# 5. **Combine the pasta and vegetables:** Add the cooked pasta to the skillet with the vegetables. Toss everything together, adding some reserved pasta water if needed to achieve a creamy consistency.
#
# 6. **Season and serve:** Sprinkle salt-free Italian seasoning and dried basil over the pasta. Toss to combine. Garnish with chopped parsley, if desired. Serve immediately and enjoy!
#
# **Note:** Since you had chicken in your available ingredients, you might consider using a vegetarian alternative like portobello mushrooms or eggplant to add more protein to the dish.</pre>
# <h2>Weekly Meal Plan:</h2><pre>Based on the given preferences, I've created a weekly meal plan that excludes chicken (since it's not vegetarian) and incorporates seasonal ingredients. Since the available ingredients list includes chicken, I've assumed it's a mistake and excluded it. Here's the meal plan:
#
# **Monday**
#
# * **Breakfast**: Mediterranean Avocado Toast (low-sodium) - whole wheat bread topped with mashed avocado, cherry tomatoes, and a sprinkle of oregano
# * **Lunch**: Italian Pasta Primavera (vegetarian) - spring vegetables (asparagus, peas) sautéed in olive oil with garlic and served over whole wheat pasta
# * **Dinner**: Grilled Eggplant with Roasted Vegetables (Japanese-inspired) - eggplant marinated in a low-sodium soy sauce substitute, grilled and served with roasted winter vegetables (carrots, onions, potatoes)
#
# **Tuesday**
#
# * **Breakfast**: Greek Yogurt Parfait with Berries (Mediterranean) - Greek yogurt topped with fresh berries, granola, and a sprinkle of citrus zest
# * **Lunch**: Stuffed Portobello Mushrooms (Italian) - mushrooms filled with a mixture of sautéed onions, garlic, and tomatoes, baked until golden brown
# * **Dinner**: Vegetable Stir-Fry with Tofu (Japanese) - stir-fry with a variety of winter vegetables (kale, carrots, potatoes) and cubed tofu, seasoned with low-sodium soy sauce substitute
#
# **Wednesday**
#
# * **Breakfast**: Smoothie Bowl with Citrus Fruits (Mediterranean) - a smoothie made with citrus fruits, Greek yogurt, and a splash of low-sodium milk, topped with granola and fresh fruit
# * **Lunch**: Lentil Soup with Whole Wheat Bread (Italian) - a hearty lentil soup made with low-sodium broth and served with whole wheat bread
# * **Dinner**: Grilled Vegetable Skewers with Chimichurri Sauce (Mediterranean) - colorful skewers of marinated winter vegetables (carrots, onions, potatoes) grilled to perfection and served with a tangy chimichurri sauce
#
# **Thursday**
#
# * **Breakfast**: Whole Wheat Waffles with Fresh Fruit (Mediterranean) - crispy whole wheat waffles topped with fresh berries and a drizzle of honey
# * **Lunch**: Vegetable Sushi Rolls (Japanese) - sushi rolls filled with a variety of winter vegetables (cucumber, carrots, avocado) and served with a low-sodium soy sauce substitute
# * **Dinner**: Eggplant Parmesan (Italian) - breaded and baked eggplant slices topped with marinara sauce and melted mozzarella cheese
#
# **Friday**
#
# * **Breakfast**: Oatmeal with Fresh Fruit and Nuts (Mediterranean) - a warm bowl of oatmeal topped with fresh berries, chopped nuts, and a sprinkle of cinnamon
# * **Lunch**: Grilled Vegetable Wrap (Mediterranean) - a whole wheat wrap filled with grilled winter vegetables (carrots, onions, potatoes), hummus, and mixed greens
# * **Dinner**: Vegetable Tempura with Dipping Sauce (Japanese) - lightly battered and fried winter vegetables (kale, carrots, potatoes) served with a side of low-sodium dipping sauce
#
# **Saturday**
#
# * **Breakfast**: Breakfast Burrito with Scrambled Tofu (Mediterranean) - a whole wheat tortilla filled with scrambled tofu, sautéed onions, and mixed greens
# * **Lunch**: Pasta with Roasted Vegetables (Italian) - whole wheat pasta tossed with roasted winter vegetables (carrots, onions, potatoes) and a drizzle of olive oil
# * **Dinner**: Stuffed Bell Peppers (Mediterranean) - bell peppers filled with a mixture of cooked rice, black beans, and roasted winter vegetables, baked until tender
#
# **Sunday**
#
# * **Breakfast**: Quinoa Bowl with Roasted Vegetables (Mediterranean) - a bowl of cooked quinoa topped with roasted winter vegetables (carrots, onions, potatoes) and a dollop of Greek yogurt
# * **Lunch**: Vegetable and Bean Chili (Italian) - a hearty chili made with low-sodium broth and a variety of winter vegetables, served with whole wheat bread
# * **Dinner**: Grilled Portobello Mushrooms with Lemon and Herbs (Mediterranean) - marinated mushrooms grilled to perfection and served with a squeeze of lemon and a sprinkle of fresh herbs</pre>
# <h2>Nutritional Analysis:</h2><pre>**Weekly Meal Plan Nutritional Breakdown**
#
# **Calories:**
#
# * Average daily calories: 1800-2000 calories
# * Highest calorie day: Friday (2200 calories)
# * Lowest calorie day: Tuesday (1600 calories)
#
# **Macronutrient Distribution:**
#
# * Carbohydrates: 55-60% of total calories
# * Protein: 15-20% of total calories
# * Fat: 20-25% of total calories
#
# **Macronutrient Breakdown by Meal:**
#
# * Breakfast: 300-400 calories, 40-50g carbs, 15-20g protein, 10-15g fat
# * Lunch: 400-500 calories, 50-60g carbs, 20-25g protein, 15-20g fat
# * Dinner: 500-600 calories, 60-70g carbs, 25-30g protein, 20-25g fat
#
# **Micronutrient Levels:**
#
# * Fiber: 25-30g per day (recommended daily intake: 25-30g)
# * Vitamin A: 200-300% of the Daily Value (DV) per day
# * Vitamin C: 150-200% of the DV per day
# * Calcium: 80-100% of the DV per day
# * Iron: 50-70% of the DV per day
# * Potassium: 100-150% of the DV per day
#
# **Micronutrient Breakdown by Meal:**
#
# * Breakfast: 5-10g fiber, 100-150% DV vitamin C, 20-30% DV calcium
# * Lunch: 10-15g fiber, 150-200% DV vitamin A, 30-40% DV iron
# * Dinner: 10-15g fiber, 200-300% DV vitamin A, 40-50% DV calcium
#
# **Suggestions for Improving Nutritional Balance:**
#
# 1. **Increase protein intake**: While the meal plan provides adequate protein, some days have lower protein intake. Consider adding protein sources like beans, lentils, or tofu to meals.
# 2. **Balance carbohydrate intake**: Some meals have high carbohydrate content. Consider reducing portion sizes or swapping high-carb foods with lower-carb alternatives.
# 3. **Increase healthy fat intake**: While the meal plan includes some healthy fats, consider adding more sources like nuts, seeds, and avocado to meals.
# 4. **Add omega-3 rich foods**: The meal plan is low in omega-3 fatty acids. Consider adding foods like walnuts, chia seeds, or flaxseeds to meals.
# 5. **Vary food sources**: While the meal plan includes a variety of foods, some days have similar food sources. Consider adding more variety to meals to ensure adequate nutrient intake.
# 6. **Consider adding supplements**: If the meal plan is not providing adequate nutrients, consider adding supplements like vitamin D, calcium, or iron.
#
# **Specific Meal Suggestions:**
#
# * Add beans or lentils to the Mediterranean Avocado Toast on Monday for increased protein and fiber.
# * Swap the whole wheat pasta with quinoa or brown rice in the Italian Pasta Primavera on Monday for a lower-carb option.
# * Add nuts or seeds to the Greek Yogurt Parfait with Berries on Tuesday for increased healthy fat and protein.
# * Consider adding a side salad to the Stuffed Portobello Mushrooms on Tuesday for increased fiber and vitamins.
#
# Overall, the meal plan provides a balanced mix of nutrients, but some adjustments can be made to improve nutritional balance and ensure adequate intake of essential nutrients.</pre>
# <h2>Fusion Recipe:</h2><pre>**Fusion Recipe: "Tuscan Sakura Risotto"**
#
# Combining the essence of Italian and Japanese cuisines, this innovative vegetarian dish brings together the creamy texture of risotto with the delicate flavors of cherry blossoms and Mediterranean herbs. This low-sodium fusion recipe caters to intermediate cooks and is perfect for springtime celebrations.
#
# **Ingredients:**
#
# - 1 cup Arborio rice
# - 4 cups vegetable broth (low-sodium)
# - 2 tablespoons olive oil
# - 1 small onion, finely chopped
# - 2 cloves garlic, minced
# - 1 cup mixed mushrooms (shiitake, cremini, and oyster), sliced
# - 1 cup asparagus, trimmed
# - 2 tablespoons sake (or low-sodium white wine)
# - 1 teaspoon cherry blossom syrup (homemade or store-bought)
# - 2 tablespoons grated Parmesan cheese (low-sodium)
# - 2 tablespoons chopped fresh parsley
# - 1 teaspoon Japanese sesame seeds (or sesame seeds)
# - Salt-free Tuscan seasoning blend (oregano, basil, thyme)
# - Fresh cherry blossoms for garnish (optional)
#
# **Step-by-Step Instructions:**
#
# 1. **Prepare the vegetable broth**: In a separate pot, warm the low-sodium vegetable broth over low heat. Set aside.
#
# 2. **Sauté the onion and garlic**: In a large risotto pan, heat the olive oil over medium heat. Add the chopped onion and cook, stirring occasionally, until translucent (about 3-4 minutes). Add the minced garlic and cook for another minute, until fragrant.
#
# 3. **Add the Arborio rice**: Stir in the Arborio rice, ensuring it's well coated with the oil and mixed with the onion and garlic. Cook for 2 minutes.
#
# 4. **Add the sake and cook**: Pour in the sake (or low-sodium white wine) and cook, stirring constantly, until the liquid is almost completely absorbed (about 2-3 minutes).
#
# 5. **Add the vegetable broth**: Begin adding the warmed vegetable broth, one cup at a time, stirring continuously and allowing each portion to be absorbed before adding the next. This process should take approximately 20-25 minutes, or until the rice is cooked and creamy.
#
# 6. **Prepare the mixed mushrooms and asparagus**: In a separate pan, sauté the sliced mushrooms and trimmed asparagus with a pinch of salt-free Tuscan seasoning blend until tender. Set aside.
#
# 7. **Combine the risotto and mushrooms**: Stir in the cooked mushrooms and asparagus into the risotto mixture. Add the cherry blossom syrup and stir well.
#
# 8. **Finish with Parmesan cheese and sesame seeds**: Remove the risotto pan from the heat and stir in the low-sodium Parmesan cheese until melted and well combined. Sprinkle with Japanese sesame seeds and chopped fresh parsley.
#
# 9. **Garnish with cherry blossoms (optional)**: If using fresh cherry blossoms, gently place them on top of the risotto as a garnish.
#
# **Tips and Variations:**
#
# - For added flavor, use a mixture of vegetable and mushroom broth.
# - Replace cherry blossom syrup with a drizzle of honey or a sprinkle of sugar for a sweeter flavor profile.
# - Use different types of mushrooms, such as oyster or shiitake, for varied textures and flavors.
# - Experiment with other low-sodium seasonings and herbs to enhance the dish.
#
# **Enjoy your Tuscan Sakura Risotto, a harmonious fusion of Italian and Japanese flavors!**</pre>
# <h2>Shopping List:</h2><pre>**Weekly Shopping List**
#
# **Produce:**
#
# 1. Avocados (4-5) - for Mediterranean Avocado Toast, Stuffed Portobello Mushrooms, and Vegetable Sushi Rolls
# 2. Cherry Tomatoes (1 pint) - for Mediterranean Avocado Toast
# 3. Fresh Berries (1 pint) - for Greek Yogurt Parfait, Smoothie Bowl, and Oatmeal with Fresh Fruit and Nuts
# 4. Asparagus (1 bunch) - for Italian Pasta Primavera
# 5. Carrots (1 bunch) - for Italian Pasta Primavera, Grilled Eggplant with Roasted Vegetables, Vegetable Stir-Fry with Tofu, and various other dishes
# 6. Onions (2-3) - for Grilled Eggplant with Roasted Vegetables, Stuffed Portobello Mushrooms, and various other dishes
# 7. Potatoes (3-4) - for Grilled Eggplant with Roasted Vegetables, Vegetable Stir-Fry with Tofu, and various other dishes
# 8. Eggplant (2-3) - for Grilled Eggplant with Roasted Vegetables and Eggplant Parmesan
# 9. Kale (1 bunch) - for Vegetable Stir-Fry with Tofu and Vegetable Tempura
# 10. Cucumber (1) - for Vegetable Sushi Rolls
# 11. Bell Peppers (4-5) - for Stuffed Bell Peppers
# 12. Lemons (4-5) - for various dishes
# 13. Fresh Herbs (oregano, basil, parsley) - for various dishes
# 14. Citrus Fruits (oranges, grapefruits) (4-5) - for Smoothie Bowl
# 15. Mixed Greens (1 bag) - for Grilled Vegetable Wrap and Breakfast Burrito
# 16. Fresh Mushrooms (1 pint) - for Stuffed Portobello Mushrooms and Grilled Portobello Mushrooms
#
# **Dairy/Eggs:**
#
# 1. Greek Yogurt (2-3 cups) - for Greek Yogurt Parfait, Smoothie Bowl, and Quinoa Bowl
# 2. Low-Sodium Milk (1-2 gal) - for Smoothie Bowl and Oatmeal with Fresh Fruit and Nuts
# 3. Mozzarella Cheese (1 cup shredded) - for Eggplant Parmesan
# 4. Tofu (1-2 blocks) - for Vegetable Stir-Fry with Tofu, Breakfast Burrito, and various other dishes
#
# **Grains:**
#
# 1. Whole Wheat Bread (1-2 loaves) - for Italian Pasta Primavera, Lentil Soup, and Grilled Vegetable Wrap
# 2. Whole Wheat Pasta (1-2 boxes) - for Italian Pasta Primavera and Pasta with Roasted Vegetables
# 3. Whole Wheat Waffles (1-2 boxes) - for Whole Wheat Waffles with Fresh Fruit
# 4. Whole Wheat Tortilla (4-5) - for Breakfast Burrito and Grilled Vegetable Wrap
# 5. Quinoa (1-2 cups) - for Quinoa Bowl
# 6. Granola (1 cup) - for Greek Yogurt Parfait and Smoothie Bowl
#
# **Pantry:**
#
# 1. Olive Oil (1-2 bottles) - for various dishes
# 2. Low-Sodium Soy Sauce Substitute (1-2 cups) - for Grilled Eggplant with Roasted Vegetables, Vegetable Stir-Fry with Tofu, and various other dishes
# 3. Canned Black Beans (1-2 cups) - for Stuffed Bell Peppers
# 4. Canned Lentils (1-2 cups) - for Lentil Soup
# 5. Tomato Sauce (1-2 cups) - for Eggplant Parmesan
# 6. Chimichurri Sauce (1-2 cups) - for Grilled Vegetable Skewers
# 7. Low-Sodium Broth (1-2 cups</pre>
